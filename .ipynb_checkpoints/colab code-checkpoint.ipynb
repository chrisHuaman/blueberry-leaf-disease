# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !git reset --hard 064365d8683fd002e9ad789c1e91fa3d021b44f0
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16512, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 16512 (delta 41), reused 49 (delta 15), pack-reused 16408
# Receiving objects: 100% (16512/16512), 15.18 MiB | 10.25 MiB/s, done.
# Resolving deltas: 100% (11304/11304), done.
# /content/yolov5
# HEAD is now at 064365d8 Update parse_opt() in export.py to work as in train.py (#10789)

# %%
# !pip install -qr requirements.txt
import torch
from IPython.display import Image, clear_output
from utils.downloads import attempt_download
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.7 MB/s eta 0:00:00
# Setup complete. Using torch 2.1.0+cu121 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15102MB, multi_processor_count=40)

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="IaQzJI2myT6FG2rBaPMN")
project = rf.workspace("graduation-project-2023").project("plants-diseases-detection-and-classification")
version = project.version(12)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Plants-Diseases-Detection-and-Classification-12 in yolov5pytorch:: 100%|██████████| 5044/5044 [00:01<00:00, 4157.50it/s]

# %%
# %cd /content/yolov5
# %cat {dataset.location}/data.yaml
# Out:
# /content/yolov5
# names:
# - Apple Scab Leaf
# - Apple leaf
# - Apple rust leaf
# - Bell_pepper leaf spot
# - Bell_pepper leaf
# - Blueberry leaf
# - Cherry leaf
# - Corn Gray leaf spot
# - Corn leaf blight
# - Corn rust leaf
# - Peach leaf
# - Potato leaf early blight
# - Potato leaf late blight
# - Potato leaf
# - Raspberry leaf
# - Soyabean leaf
# - Squash Powdery mildew leaf
# - Strawberry leaf
# - Tomato Early blight leaf
# - Tomato Septoria leaf spot
# - Tomato leaf bacterial spot
# - Tomato leaf late blight
# - Tomato leaf mosaic virus
# - Tomato leaf yellow virus
# - Tomato leaf
# - Tomato mold leaf
# - Tomato two spotted spider mites leaf
# - grape leaf black rot
# - grape leaf
# nc: 29
# roboflow:
#   license: CC BY 4.0
#   project: plants-diseases-detection-and-classification
#   url: https://universe.roboflow.com/graduation-project-2023/plants-diseases-detection-and-classification/dataset/12
#   version: 12
#   workspace: graduation-project-2023
# ...

# %%
import yaml
with open(dataset.location + "/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, GPL-3.0 license
#
# # Parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
# ...

# %%
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
# # parameters
# nc: {num_classes}
# depth_multiple: 0.33
# width_multiple: 0.50
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]
#   - [30,61, 62,45, 59,119]
#   - [116,90, 156,198, 373,326]
#
# # YOLOv5 backbone
# backbone:
#   [[-1, 1, Focus, [64, 3]],
#    [-1, 1, Conv, [128, 3, 2]],
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP, [512, False]],
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP, [256, False]],
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP, [512, False]],
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP, [1024, False]],
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],
#   ]

# %%
# %%time
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 170 --data {dataset.location}/data.yaml --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# /content/yolov5
# 2024-03-08 08:56:01.067009: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-08 08:56:01.067075: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-08 08:56:01.068482: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-08 08:56:02.166683: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
from IPython.display import Image, display
image_path = '/content/yolov5/runs/train/yolov5s_results/results.png'
display(Image(filename=image_path, width=1000))

# %%
Image(filename='/content/yolov5/runs/train/yolov5s_results/val_batch0_labels.jpg', width=900)

# %%
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/train_batch0.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %%
# %ls runs/train/yolov5s_results/weights
# Out:
# best.pt  last.pt

# %%
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.4 --source /content/Plants-Diseases-Detection-and-Classification-12/test/images
# Out:
# /content/yolov5
# detect: weights=['runs/train/yolov5s_results/weights/best.pt'], source=/content/Plants-Diseases-Detection-and-Classification-12/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d8 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7322034 parameters, 0 gradients
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/249 /content/Plants-Diseases-Detection-and-Classification-12/test/images/022_jpg.rf.db03fecdb4b0082ef982753c6efe4528.jpg: 416x416 1 Corn rust leaf, 12.0ms
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files

# Download the file from the specified path
files.download('/content/yolov5/runs/train/yolov5s_results/weights/best.pt')

# %%
# %cd /content/yolov5/
# Out:
# /content/yolov5

# %%
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.4 --source /content/test/corn_leaf_striping_V8.jpg
# Out:
# detect: weights=['runs/train/yolov5s_results/weights/best.pt'], source=/content/test/corn_leaf_striping_V8.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d8 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7322034 parameters, 0 gradients
# image 1/1 /content/test/corn_leaf_striping_V8.jpg: 416x384 1 Corn leaf blight, 56.6ms
# Speed: 0.4ms pre-process, 56.6ms inference, 513.7ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp5

# %%
# !python detect.py --weights /content/best.pt --img 416 --conf 0.4 --source /content/test/corn_leaf_striping_V8.jpg
# Out:
# detect: weights=['/content/best.pt'], source=/content/test/corn_leaf_striping_V8.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d8 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7322034 parameters, 0 gradients
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/test/corn_leaf_striping_V8.jpg: 416x384 1 Corn leaf blight, 53.3ms
# Speed: 0.5ms pre-process, 53.3ms inference, 751.2ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp6

# %%
# !zip -r /content/yolov5.zip /content/yolov5
# Out:
#   adding: content/yolov5/ (stored 0%)
#   adding: content/yolov5/.dockerignore (deflated 56%)
#   adding: content/yolov5/runs/ (stored 0%)
#   adding: content/yolov5/runs/detect/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp3/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp3/download.jpg (deflated 8%)
#   adding: content/yolov5/runs/detect/exp/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp/5944718_f1024_jpg.rf.c0272bf19a3520650f00ddfc0c77e146.jpg (deflated 3%)
#   adding: content/yolov5/runs/detect/exp/Bell-pepper-plant-JPG_jpg.rf.072ba7b994cf3600e558d28009ff6958.jpg (deflated 4%)
#   adding: content/yolov5/runs/detect/exp/potato_ocw_lateblight-earlyblight_jpg.rf.b279ae70e141d756ed07ea69d04392e8.jpg (deflated 4%)
#   adding: content/yolov5/runs/detect/exp/2013-08-20-06_jpg.rf.134fd575dd91ca574c501c6b575b020f.jpg (deflated 3%)
#   adding: content/yolov5/runs/detect/exp/curling-issues_jpg.rf.d228154453ff455b8b3cd99bfb9f40db.jpg (deflated 3%)
# ...

# %%
from google.colab import files

files.download('/content/yolov5.zip')
